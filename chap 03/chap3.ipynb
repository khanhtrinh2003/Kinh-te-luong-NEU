# %%
library(hexView)
library(car)
library(ggplot2)
# Out:
# Warning message:
# "package 'car' was built under R version 4.2.2"
# Loading required package: carData
#
# Warning message:
# "package 'carData' was built under R version 4.2.2"
# Warning message:
# "package 'ggplot2' was built under R version 4.2.2"

# %% [markdown]
# ### Bài 3.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 1.1)
#
# $H_0: \beta_L=0$
#
# $H_1: \beta_L\not =0$
#
# $t_{qs}=\frac{-12.4}{1.96}=-6.327$
#
# $t_{0.025}(188-3)=1.973$
#
# $|t_{qs}|>1.973$
#
# Với mức ý nghĩa 5%, số lao động có tác động đến năng suất trung bình
#
# ##### 1.2)
#
# $$
# \hat\beta_L -t^{n-k}_{\frac \alpha2}se(\hat\beta_L)<\beta_L<\hat\beta_L +t_{\frac \alpha2}^{n-k}se(\hat\beta_L)\\
#
# -15.907<\beta_L<-8.558
# $$
#
# ##### 1.3)
#
# $H_0:\beta_K+ \beta_L=0$
#
# $H_1: \beta_K+ \beta_L<0$
#
# $se(\hat\beta_K+\hat\beta_L)=\sqrt{se^2(\hat\beta_K)+se^2(\hat\beta_L)+Cov(\hat\beta_K,\hat\beta_L)}=1.96$
#
# $$
# ⁍
# $$
#
# $|t_{qs}|>t_{0.05}(188-3)$
#
# Với mức ý nghĩa 5%, năng suất trung bình giảm
#
# ##### 1.4)
#
# $H_0:\beta_K= \beta_L=0$
#
# $H_1: \beta_K^2+ \beta_L^2>0$
#
# $$
# F_{qs}=\frac{R^2/(k-1)}{(1-R^2)/(n-k)}=412.96>f_{0.05}(2;185)
# $$
#
# Với mức ý nghĩa 5% hàm hồi quy là phù hợp

# %% [markdown]
# ### Bài 3.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# F=\frac{(R^2_{ur}-R^2_{r})/m}{(1-R^2_{ur})/(n-k)}=\frac{(0.821-0.817)/2}{(1-0.821)/185}=2.067<f^{(2;185)}_{0.05}
# $$
#
# Với mức ý nghĩa 5% PC và Age không tác động đến NS trung bình

# %% [markdown]
# ### Bài 3.3

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ##### 3.1)
#
# $$
# \hat\beta_L -t^{n-k}_{\frac \alpha2}se(\hat\beta_L)<\beta_L<\hat\beta_L +t_{\frac \alpha2}^{n-k}se(\hat\beta_L)\\
#
# -0.807<\beta_L<-0.373
# $$
#
# Với mức ý nghĩa 5% NS trung bình giảm (0.373; 0.807)%
#
# ##### 3.2)
#
# $H_0:\beta_K+ \beta_L=0$
#
# $H_1: \beta_K+ \beta_L\not=0$
#
# $se(\hat\beta_K+\hat\beta_L)=\sqrt{se^2(\hat\beta_K)+se^2(\hat\beta_L)+Cov(\hat\beta_K,\hat\beta_L)}=0.0837$
#
# $$
# t_{qs}=\frac{0.77-0.59-0}{se(\hat\beta_K+\hat\beta_L)}=2.15>t^{185}_{0.025}
# $$
#
# $|t_{qs}|>t_{0.05}(188-3)$
#
# Với mức ý nghĩa 5%, năng suất trung bình thay đổi
#
# ##### 3.3)
#
# Theo quy luật năng suất cận biên giảm dần, khi L tăng thì Sản lượng tăng bé  hơn L nên NS giảm ⇒ Hệ số âm
#
# ##### 3.4)
#
# Không thể vì biến phụ thuộc khác nhau

# %% [markdown]
# ### Bài 3.4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bai4 <- readEViews("ch3bt4.wf1")
# Out:
# Warning message in readEViews("ch3bt4.wf1"):
# "Skipping boilerplate variable
# "
# Warning message in readEViews("ch3bt4.wf1"):
# "Skipping boilerplate variable
# "

# %%
hq4 <- lm(data=bai4, CT~TN+TS+TNP)
summary(hq4)
# Out:
# Call:
# lm(formula = CT ~ TN + TS + TNP, data = bai4)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -19.483 -10.309  -0.031   7.923  34.164
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 16.63402    8.44971   1.969  0.05800 .
# TN           0.81363    0.03045  26.722  < 2e-16 ***
# TS           0.04984    0.01459   3.417  0.00179 **
# TNP         -0.32324    0.17339  -1.864  0.07178 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 14.29 on 31 degrees of freedom
# Multiple R-squared:  0.9996,	Adjusted R-squared:  0.9995
# F-statistic: 2.452e+04 on 3 and 31 DF,  p-value: < 2.2e-16

# %% [markdown]
# 4.1) Với mức 5%, TS có ý nghĩa
#
# 4.2) Với mức 5%, TNP không có ý nghĩa

# %% [markdown]
# ##### Kiểm định F

# %%
hq4 <- lm(data=bai4, CT~TN+TS+TNP)
summary(hq4)
# Out:
# Call:
# lm(formula = CT ~ TN + TS + TNP, data = bai4)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -19.483 -10.309  -0.031   7.923  34.164
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 16.63402    8.44971   1.969  0.05800 .
# TN           0.81363    0.03045  26.722  < 2e-16 ***
# TS           0.04984    0.01459   3.417  0.00179 **
# TNP         -0.32324    0.17339  -1.864  0.07178 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 14.29 on 31 degrees of freedom
# Multiple R-squared:  0.9996,	Adjusted R-squared:  0.9995
# F-statistic: 2.452e+04 on 3 and 31 DF,  p-value: < 2.2e-16

# %%
hq43 <- lm(data=bai4, CT~TN)
summary(hq43)
# Out:
# Call:
# lm(formula = CT ~ TN, data = bai4)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -47.880  -7.204   0.369  14.438  31.805
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 47.88009    8.71229   5.496 4.27e-06 ***
# TN           0.86622    0.00461 187.909  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 20.62 on 33 degrees of freedom
# Multiple R-squared:  0.9991,	Adjusted R-squared:  0.999
# F-statistic: 3.531e+04 on 1 and 33 DF,  p-value: < 2.2e-16

# %%
ur <- summary(hq4)$r.squared
rr <- summary(hq43)$r.squared
F=((ur-rr)/2)/((1-ur)/(length(bai4$CT)-4))
F
# Out:
# [1] 18.86309

# %%
pf(F,2,(length(bai4$CT)-4))
# Out:
# [1] 0.9999956

# %% [markdown]
# ##### Kiểm định Wald

# %%
install.packages("car")
# Out:
# Warning message:
# "package 'car' is in use and will not be installed"

# %%
linearHypothesis(hq4,c("TS=0","TNP=0"))
# Out:
#   Res.Df RSS       Df Sum of Sq F        Pr(>F)
# 1 33     14027.479 NA       NA        NA           NA
# 2 31      6327.311  2 7700.168  18.86309 4.372331e-06

# %%
cor(bai4$TNP, bai4$TS)
# Out:
# [1] 0.9977786

# %% [markdown]
# ##### LR test

# %%
library(lmtest)
lrtest(hq4, hq43)
# Out:
#   #Df LogLik    Df Chisq  Pr(>Chisq)
# 1 5   -140.6153 NA     NA           NA
# 2 3   -154.5478 -2 27.865 8.895945e-07

# %% [markdown]
# ### Bài 3.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hq51 <- lm(data=bai4, CT~TN+TS)
hq52 <- lm(data=bai4, CT~TN+TNP)

# %%
summary(hq51)
# Out:
# Call:
# lm(formula = CT ~ TN + TS, data = bai4)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -24.863  -9.330  -0.652   8.538  35.082
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 24.862657   7.478692   3.324  0.00223 **
# TN           0.766884   0.017928  42.777  < 2e-16 ***
# TS           0.023724   0.004208   5.638  3.1e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 14.83 on 32 degrees of freedom
# Multiple R-squared:  0.9995,	Adjusted R-squared:  0.9995
# F-statistic: 3.414e+04 on 2 and 32 DF,  p-value: < 2.2e-16

# %%
summary(hq52)
# Out:
# Call:
# lm(formula = CT ~ TN + TNP, data = bai4)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -34.859  -9.424  -0.606   9.737  35.249
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 34.85906    7.56899   4.606 6.23e-05 ***
# TN           0.74744    0.02713  27.550  < 2e-16 ***
# TNP          0.24595    0.05565   4.419 0.000106 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 16.5 on 32 degrees of freedom
# Multiple R-squared:  0.9994,	Adjusted R-squared:  0.9994
# F-statistic: 2.758e+04 on 2 and 32 DF,  p-value: < 2.2e-16

# %% [markdown]
# 5.3)
# Từng biến đều có tác động, nhưng khi gộp thì làm mô hình bị lỗi
#
# 5.4) $R^2$ và $\overline R^2$ gần như giống nhau. Nếu chọn thì chọn mô hình 2 tại CT nhạy cảm vs TNP hơn

# %% [markdown]
# ### Bài 3.6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6.1) Khi TN=TS=1 thì chi tiêu trung bình là $e^{0.08456}$
#
# 6.2) Với mức ý nghĩa 5% thì TS không có ý nghĩa thống kê
#
# 6.3) Có thể cho rằng
#
# 6.4) Không có vấn đề vì nó không có tác động

# %% [markdown]
# ### Bài 3.7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bai7 <- readEViews("ch3bt7.wf1")
# Out:
# Warning message in readEViews("ch3bt7.wf1"):
# "Skipping boilerplate variable
# "
# Warning message in readEViews("ch3bt7.wf1"):
# "Skipping boilerplate variable
# "

# %%
hoiquyboi <- lm(data=bai7,Q~K)

# %%
summary(hoiquyboi)
# Out:
# Call:
# lm(formula = Q ~ K, data = bai7)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -19.6944 -10.1369   0.7506  12.0615  17.2526
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -35.72      28.00  -1.276    0.211
# K            1208.23     153.09   7.892 5.26e-09 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 12.26 on 32 degrees of freedom
# Multiple R-squared:  0.6606,	Adjusted R-squared:   0.65
# F-statistic: 62.29 on 1 and 32 DF,  p-value: 5.255e-09

# %%
sum(resid(hoiquyboi)^2)
# Out:
# [1] 4808.489

# %% [markdown]
# ### Bài 3.8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hoiquyboi <- lm(data=bai7,Q~L)
summary(hoiquyboi)
# Out:
# Call:
# lm(formula = Q ~ L, data = bai7)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -19.696  -1.983   1.451   4.410  11.300
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -146.897     22.537  -6.518 2.44e-07 ***
# L             39.996      2.715  14.734 8.22e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 7.542 on 32 degrees of freedom
# Multiple R-squared:  0.8715,	Adjusted R-squared:  0.8675
# F-statistic: 217.1 on 1 and 32 DF,  p-value: 8.219e-16

# %%
sum(resid(hoiquyboi)^2)
# Out:
# [1] 1820.24

# %% [markdown]
# ### Bài 3.9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hoiquyboi <- lm(data=bai7,Q~K+L)
summary(hoiquyboi)
# Out:
# Call:
# lm(formula = Q ~ K + L, data = bai7)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -19.691  -1.982   1.443   4.418  11.323
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -146.847     23.429  -6.268 5.74e-07 ***
# K              1.973    194.291   0.010    0.992
# L             39.946      5.599   7.134 5.12e-08 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 7.663 on 31 degrees of freedom
# Multiple R-squared:  0.8715,	Adjusted R-squared:  0.8632
# F-statistic: 105.2 on 2 and 31 DF,  p-value: 1.536e-14

# %% [markdown]
# 1) Không tác động
# 2) Không mâu thuẫn do ngắn hạn nên tư bản ít tác động đến Q hơn
# 3) 87.15%

# %% [markdown]
# ### Bài 3.10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hq <- lm(data=bai7, Q~K+I(K^2))
summary(hq)
# Out:
# Call:
# lm(formula = Q ~ K + I(K^2), data = bai7)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -15.569 -10.609  -3.006   7.586  19.672
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)    613.1      257.7   2.379   0.0237 *
# K            -6108.6     2894.8  -2.110   0.0430 *
# I(K^2)       20498.0     8100.1   2.531   0.0167 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 11.34 on 31 degrees of freedom
# Multiple R-squared:  0.7187,	Adjusted R-squared:  0.7006
# F-statistic: 39.61 on 2 and 31 DF,  p-value: 2.894e-09

# %% [markdown]
# 1) $\beta_3$ là mức thay đổi khi K thay đổi. Theo quy luật năng suất cận biên giảm dần $⇒ \beta_3<0$
#
# 2) Không

# %% [markdown]
# ### Bài 3.11

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# F=\frac{(R^2_{ur}-R^2_{r})/m}{(1-R^2_{ur})/(n-k)}=\frac{(RSS_R-RSS_{UR})/m}{RSS_{UR}/(n-k)}\text{\textasciitilde} F_{m,n-k}
# $$

# %% [markdown]
# ### Bài 3.12

# %% [markdown]
# ### Bài 3.13

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bai13 <- readEViews("ch3bt13.wf1")
# Out:
# Warning message in readEViews("ch3bt13.wf1"):
# "Skipping boilerplate variable
# "
# Warning message in readEViews("ch3bt13.wf1"):
# "Skipping boilerplate variable
# "

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hoiquyboi <- lm(data = bai13, "log(Q)~log(P)+log(Y)")
summary(hoiquyboi)
# Out:
# Call:
# lm(formula = "log(Q)~log(P)+log(Y)", data = bai13)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.32845 -0.09141  0.01575  0.12545  0.36270
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 11.73637    0.33285  35.260  < 2e-16 ***
# log(P)      -0.75409    0.05280 -14.283 4.19e-14 ***
# log(Y)       0.15828    0.04907   3.226  0.00328 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.178 on 27 degrees of freedom
# Multiple R-squared:  0.9526,	Adjusted R-squared:  0.9491
# F-statistic: 271.1 on 2 and 27 DF,  p-value: < 2.2e-16

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
linearHypothesis(hoiquyboi, "log(P)=-1")
# Out:
#   Res.Df RSS       Df Sum of Sq F        Pr(>F)
# 1 28     1.5430958 NA        NA       NA           NA
# 2 27     0.8556359  1 0.6874598 21.69312 7.644368e-05

# %%
linearHypothesis(hoiquyboi, c("log(P)=-1","log(Y)=1"))
# Out:
#   Res.Df RSS        Df Sum of Sq F        Pr(>F)
# 1 29     27.2128076 NA       NA        NA           NA
# 2 27      0.8556359  2 26.35717  415.8566 5.205489e-21

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
confint(hoiquyboi, level=0.95)
# Out:
#             2.5 %       97.5 %
# (Intercept) 11.05342528 12.4193238
# log(P)      -0.86242107 -0.6457557
# log(Y)       0.05760385  0.2589605

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
var2 <- vcov(hoiquyboi)[2,2]
var3 <- vcov(hoiquyboi)[3,3]
cov23 <- vcov(hoiquyboi)[3,2]

# %%
se <- sqrt(var2+var3+2*cov23)
beta2 <- -0.7541 
beta3 <- 0.1583

# %%
can_tren <- (beta2+beta3)+qt(0.975,27)*se

# %%
can_duoi <- (beta2+beta3)-qt(0.975,27)*se

# %%
can_duoi
can_tren
# Out:
# [1] -0.7883653
# [1] -0.4032347

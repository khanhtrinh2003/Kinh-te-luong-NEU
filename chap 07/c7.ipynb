# %% [markdown]
# # Bài 7.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $E(u_t)=E(1.5u_{t-1}+\epsilon_t)=E(1.5u_{t-1})+E(\epsilon_t)\\
# E(u_t)=1.5E(u_{t-1})=1.5^{t}E(u_0)
# $
#
# Vậy kỳ vọng của $u_t$ thay đổi theo thời gian nên không là chuỗi dừng

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# Q_t=\lambda\beta_1+\beta_2\lambda P_{t-1}+(1-\lambda)Q_{t-1}+v_t
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# m_t=\lambda\beta_1+\beta_2\lambda \Delta p_t+(1-\lambda)m_{t-1}+v_t
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1) $\lambda=1-0.021$
#
# 2) -0.01
#
# 3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# Q_t=\beta_1\delta+\beta_2\delta P_{t}+(1-\delta)Q_{t-1}+\delta u_t
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Mô hình kỳ vọng thích nghi:
# - Mục đích: Dự đoán dựa vào kỳ vọng
# - Kỹ thuật:
# $$
# Y_t=\beta_1+\beta_2P^*_t+u_t
# $$
#
# - $P_t^*-P^*_{t-1}=\lambda (P_{t-1}-P^*_{t-1})$
#     - Hệ số điều chỉnh của quá trình thích nghi: $\lambda$
#     - $0≤\lambda≤1$
#     - $P_t^*=\lambda P_{t-1}+(1-\lambda)P^*_{t-1}$
#     - $P_t^*=\lambda P_{t-1}+\lambda(1-\lambda)P_{t-2}+\lambda(1-\lambda)^2P_{t-3}+...$
#
# $$
# \begin{aligned}
# &Y_t=\beta_1+\beta_2\lambda P_{t-1}+\beta_2\lambda(1-\lambda) P_{t-2}+\beta_2\lambda(1-\lambda)^2 P_{t-3}+...+u_t
# \\
# &Y_t=\lambda\beta_1+\beta_2\lambda P_{t-1}+(1-\lambda)Y_{t-1}+v_t
# \end{aligned}
# $$
#
# Mô hình hiệu chỉnh từng phần:
# - Mục đích: Dự đoán giá trị cân bằng dài hạn (kỳ vọng) dựa vào các yếu tố
# - Kỹ thuật:
# $$
# Y_t^*=\beta_1+\beta_2X_t+u_t
# $$
#
# - $Y_t-Y_{t-1}=\delta(Y_{t-1}-Y^*_{t-1})$
#     - $Y_t=\delta Y^*_{t}+(1-\delta )Y_{t-1}$
#     - $\begin{aligned}
#     Y_t&=\delta (\beta_1+\beta_2X_t+u_t)+(1-\lambda)[\delta Y^*_{t-1}+(1-\lambda)Y_{t-1}]\\
#     &=\delta\beta_1\sum^\infty_{i=0}(1-\delta)^i+\delta\beta_2X_t+\delta\beta_2(1-\delta)X_{t-1}+\delta\beta_2(1-\delta)^2X_{t-2}
#     +...+v_t\\
#     &=\beta_1+\delta\beta_2X_t+\delta\beta_2(1-\delta)X_{t-1}+\delta\beta_2(1-\delta)^2X_{t-2}
#     +...+v_t
#     \end{aligned}$
#         - $v_t=\delta\sum^\infty_{i=0}(1-\delta)^iu_{t-i}$
#
# $$
# Y_t=\beta_1\delta+\beta_2\delta X_{t}+(1-\delta)Y_{t-1}+\delta u_t
# $$
#
# - $\delta:$ Hệ số điều chỉnh, nó cho biết quá trình hiệu chỉnh để $Y_t$ ảnh hưởng tới giá trị cân bằng dài hạn $Y^*_t$ là nhanh hay chậm
# - $\beta_2:$ Đo lường tác động của biến $X_t$ lên giá trị cân bằng dài hạn $Y^*_t$
# - $\beta_2\delta:$ Đo lường tác động tức thời của biến $X_t$ lên giá trị thực tế $Y_t$

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

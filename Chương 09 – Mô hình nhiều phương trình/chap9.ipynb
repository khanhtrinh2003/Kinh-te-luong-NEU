# %% [markdown]
# ![image.png](attachment:image.png)
# 1)
# Mô hình xác định
#
# ![image-2.png](attachment:image-2.png)
#
# Mô hình ngẫu nhiên
#
# ![image-3.png](attachment:image-3.png)
#
# 2)
# - Biến nội sinh: biến mà giá trị của nó được xác định từ mô hình
# - Biến ngoại sinh: các giá trị của nó được xác định ngoài mô hình (bao gồm cả biến trễ của biến nội sinh, của biến ngoại sinh, biến ngoại sinh trễ, hệ số chặn)
#
# 3)
# - Phương trình cấu trúc (phương trình hành vi) bắt nguồn từ lý thuyết kinh tế có giải thích nguyên nhân. Các phương trình cấu trúc cũng có thể là các phương trình định nghĩa, phương trình phản ánh cấu trúc của nền kinh tế, doanh nghiệp
#
# 4)
# - Phương trình rút gọn là phương trình biểu diễn một cách duy nhất một biến nội sinh với các biến ngoại sinh và yếu tố ngẫu nhiên

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# GDP phụ thuộc vào cung tiền danh nghĩa
#
# Nhập khẩu phụ thuộc vào GDP
#
# Tài khoản ngoại tệ phụ thuộc vào xuất khẩu, nhật khẩu, vốn, và tài khoản trước đó
#
# ![image-3.png](attachment:image-3.png)
#
# $$
# \begin{aligned}
# &F_t=F_{t-1}+X_t-M_t+K_t=F_{t-1}+X_t-mY_t+K_t\\
# &M_0=D_t+F_t=D_t+F_{t-1}+X_t-mY_t+K_t\\
# &Y_t=vM_{0t}=v(D_t+F_{t-1}+X_t-mY_t+K_t)\\
# &\Rarr Y_t=\frac{vD_t+vF+{t-1}+vX_t+v_{K_t}}{1+v\times m}
# \end{aligned}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# - $T_t$ trong mô hình A là biến ngoại sinh
# - $T_t$ trong mô hình B là biến nội sinh
#
# ![image-4.png](attachment:image-4.png)
#
# Mô hình A:
# $$
# Y_t=C_t+I_t+G_t=\beta_1+\beta_2(Y_t-T_t)+I_t+G_t\\
# Y_t=\frac{\beta_1-\beta_2T_t+I_t+G_t}{1-\beta_2}
# $$
#
# Mô hình B:
# $$
# Y_t=C_t+I_t+G_t=\beta_1+\beta_2(Y_t-T_t)+I_t+G_t\\
# Y_t=\frac{\beta_1+I_t+G_t}{1-\beta_2(1-\beta_3)}
# $$
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# -  `M`: số biến nội sinh = 3($Q_D,Q_S,P$);
# - `K`: số biến ngoại sinh của mô hình (kể cả hệ số chặn)=3($1,Y,W)
#
# ![image-2.png](attachment:image-2.png)
# - Xét một phương trình cụ thể có `m` biến nội sinh, `k` biến ngoại sinh.
# - Để phương trình nói trên là định dạng được thì: K-k>=m-1
#     - Khi K-k = m-1: phương trình định dạng đúng
#     - Khi K-k >m-1: phương trình vô định
#
# - pt 1: k=2,m=2 K-k=M-m: phương trình định dạng đúng
# - pt 2: k=2,m=2 K-k=M-m: phương trình định dạng đúng
# - pt 3: k=0,m=2 K-k>M-m: phương trình vô định
#
# ![image-3.png](attachment:image-3.png)
# $$
# \begin{aligned}
# &Q_D=Q_S\Rarr\alpha_1+\alpha_2P+\alpha_3Y+u_t=\beta_1+\beta_2P+\beta_3Y+u_2\\
# &\Lrarr P=\frac{1}{\alpha_2-\beta_2}(-\alpha_1+\beta_1+\beta_3Y_t+u_2-u_t)\\
# &\Lrarr Q_D=\alpha_1+\frac{\alpha_2}{\alpha_2-\beta_2}(-\alpha_1+\beta_1+\beta_3Y_t+u_2-u_t)+\alpha_3Y+u_t\\
# &\Lrarr Q_s=\beta_1+\frac{\beta_2}{\alpha_2-\beta_2}(-\alpha_1+\beta_1+\beta_3Y_t+u_2-u_t)+\beta_3Y+u_2
# \end{aligned}
# $$
#
# ![image-4.png](attachment:image-4.png)
#
# Bởi vì thỏa mãn điều kiện ở câu 1
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
